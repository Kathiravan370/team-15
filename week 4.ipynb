# %% [markdown]
# <a href="https://colab.research.google.com/github/Kathiravan370/team-15/blob/main/week%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
df = pd.read_csv("/content/retail_store_sales.csv")
df['Price Per Unit'] = pd.to_numeric(df['Price Per Unit'], errors='coerce')
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['Total Spent'] = pd.to_numeric(df['Total Spent'], errors='coerce')
df['Price Per Unit'].fillna(df['Price Per Unit'].mean(), inplace=True)
df['Quantity'].fillna(df['Quantity'].median(), inplace=True)
df['Total Spent'].fillna(df['Total Spent'].mean(), inplace=True)
df['Item'].fillna(df['Item'].mode()[0], inplace=True)
df['Discount Applied'].fillna('False', inplace=True)
# UNIVARIATE ANALYSIS
plt.hist(df['Quantity'], bins=20)
plt.title("Distribution of Quantity")
plt.xlabel("Quantity")
plt.ylabel("Frequency")
plt.show()
plt.hist(df['Total Spent'], bins=20)
plt.title("Distribution of Total Spending")
plt.show()
df['Payment Method'].value_counts().plot(kind='bar')
plt.title("Payment Method Usage")
plt.show()
df['Location'].value_counts().plot(kind='bar')
plt.title("Sales by Location")
plt.show()
# BIVARIATE ANALYSIS
plt.scatter(df['Quantity'], df['Total Spent'])
plt.title("Quantity vs Total Spent")
plt.xlabel("Quantity")
plt.ylabel("Total Spent")
plt.show()
df.groupby('Category')['Total Spent'].mean().plot(kind='bar')
plt.title("Average Spending by Category")
plt.show()
df.groupby('Discount Applied')['Total Spent'].mean().plot(kind='bar')
plt.title("Impact of Discount on Spending")
plt.show()
# MULTIVARIATE ANALYSIS
numeric_df = df[['Price Per Unit', 'Quantity', 'Total Spent']]
corr = numeric_df.corr()
plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap - Multivariate Analysis")
plt.show()
# Out:
# /tmp/ipython-input-1264435949.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price Per Unit'].fillna(df['Price Per Unit'].mean(), inplace=True)
# /tmp/ipython-input-1264435949.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Quantity'].fillna(df['Quantity'].median(), inplace=True)
# /tmp/ipython-input-1264435949.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Total Spent'].fillna(df['Total Spent'].mean(), inplace=True)
# /tmp/ipython-input-1264435949.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Item'].fillna(df['Item'].mode()[0], inplace=True)
# /tmp/ipython-input-1264435949.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Discount Applied'].fillna('False', inplace=True)
